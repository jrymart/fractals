# %%
from osgeo import gdal
import numpy as np
from matplotlib import pyplot as plt

# %%
dem_path="/home/jo/cub/research/data/dems/colorado/czo_1m_gg_snwOff.zip/czo_1m_gg_snowOff/czo_1m_gg_s-o/w001001.adf"

# %%
dem_ds=gdal.Open(dem_path)

# %%
dem_arr=dem_ds.GetRasterBand(1).ReadAsArray()

# %%
plt.imshow(dem_arr, norm="log")

# %%
dem_ds.GetGeoTransform()
# Out:
# (457322.50000000093, 1.0, 0.0, 4431070.5, 0.0, -1.0)

# %%
dem_ds.GetProjection()
# Out:
# 'PROJCS["unnamed",GEOGCS["NAD83",DATUM["North_American_Datum_1983",SPHEROID["GRS 1980",6378137,298.257222101,AUTHORITY["EPSG","7019"]],AUTHORITY["EPSG","6269"]],PRIMEM["Greenwich",0,AUTHORITY["EPSG","8901"]],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AUTHORITY["EPSG","4269"]],PROJECTION["Transverse_Mercator"],PARAMETER["latitude_of_origin",0],PARAMETER["central_meridian",-105],PARAMETER["scale_factor",0.9996],PARAMETER["false_easting",500000],PARAMETER["false_northing",0],UNIT["METERS",1],AXIS["Easting",EAST],AXIS["Northing",NORTH]]'

# %%
out="/vsimem/resam.tif"

# %%
reamds = gdal.Warp(out, dem_path, resampleAlg="max", xRes=100, yRes=100)

# %%
resamarr = reamds.GetRasterBand(1).ReadAsArray()

# %%
plt.imshow(resamarr, norm="log")

# %%
dem_path="/home/jo/cub/research/data/dems/hydrosheds/au_con_3s.tif"
dem_p_path = "/home/jo/cub/research/data/dems/hydrosheds/au_con

# %%
dem_ds=gdal.Open(dem_path)

# %%
dem_ds.GetGeoTransform()
# Out:
# (90.0, 0.0008333333333333328, 0.0, 30.0, 0.0, -0.000833333333333333)

# %%
proj=gdal.Warp("/home/jo/cub/research/data/dems/hydrosheds/au_coast.tif",
               dem_path,
